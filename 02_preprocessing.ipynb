# %% [markdown]
# ## Preprocessing

# %%
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from text_magic.functions import clean_to_lower

# %%
with open(file="quotes/statement_1_0.txt", mode="r", encoding="utf-8") as f:
    text = f.read()

# %%
cleaned_text = clean_to_lower(text)
print(cleaned_text)
# Out:
# “the world as we have created it is a process of our thinking. it cannot be changed without changing our thinking.”

# %%
clean_punctuation(cleaned_text)
# Out:
# 'the world as we have created it is a process of our thinking it cannot be changed without changing our thinking'
