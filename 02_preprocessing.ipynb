# %% [markdown]
# ## Preprocessing

# %%
from text_magic.functions import pipeline

# %%
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Steinwender\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
with open(file="quotes/statement_1_0.txt", mode="r", encoding="utf-8") as f:
    text = f.read()

# %%
pipeline(text)
# Out:
# 'world created process thinking cannot changed without changing thinking'

# %%
# Nebenschauplatz

from nltk.corpus import stopwords
from text_magic.functions import clean_strip

# %%
# stopwords.words('german')

# %%
text = "Beispielsatz in der Deutsch hallo welt wie geht es dir!"
pipeline(text, language='german')
# Out:
# 'beispielsatz deutsch hallo welt geht'
